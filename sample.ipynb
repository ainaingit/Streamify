# %%
import pandas as pd

# %%
movies = pd.read_csv('datas/netflix_titles.csv',index_col=0)

# %%
movies.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
movies.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
movies.dtypes
# Out:
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# verify if there is some null or undefined value and sum it for each columns 
print(movies.isnull().sum())
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# encoding types columns with Label Encoding instead of  
from sklearn.preprocessing import LabelEncoder

# Créer un LabelEncoder
label_encoder = LabelEncoder()

# Exemple : encoder la colonne 'type'
movies['type_encoded'] = label_encoder.fit_transform(movies['type'])

# %%
movies
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Appliquer One-Hot Encoding sur la colonne 'cast'
#movies_one_hot = movies['cast'].str.get_dummies(sep=', ')

# Ajouter les nouvelles colonnes encodées au dataset principal
#movies = movies.join(movies_one_hot)

#print(movies.head())

# %%
# Remplacer les NaN dans la colonne 'cast' par une chaîne vide
movies['cast'] = movies['cast'].fillna('')

# Compter le nombre d'acteurs dans chaque ligne
movies['cast_encoded'] = movies['cast'].apply(lambda x: len(x.split(',')) if x else 0)

# %%
movies
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                          United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
movies.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'type_encoded', 'cast_encoded'],
#       dtype='object')

# %%
# Fractionner les genres (listed_in) en plusieurs valeurs
# putting each list in values into a tab 
movies['genres'] = movies['listed_in'].str.split(', ')

# Exploser les genres pour faciliter l'analyse
# i.e movie 1 : drama , movie 2 : horror 
# creatin a new dataset which has movie and genre in columns' name
genres_exploded = movies.explode('genres')

# Compter les occurrences de chaque genre
#1# identify popular Genre
genre_popularity = genres_exploded['genres'].value_counts()

print("Genres les plus populaires :")
print(genre_popularity.head(10))
movies
# Out:
# Genres les plus populaires :
# genres
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# ...

# %%
# Comptage des occurrences de chaque catégorie de rating
rating_counts = movies['rating'].value_counts()

print("Répartition des Ratings :")
print(rating_counts)

# Visualisation de la répartition des ratings
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
rating_counts.plot(kind='bar', color='skyblue')
plt.title("Répartition des Ratings")
plt.xlabel("Catégories de Ratings")
plt.ylabel("Nombre de Contenus")
plt.xticks(rotation=45)
plt.show()
# Out:
# Répartition des Ratings :
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
# Filtrer les genres contenant 'Drama'
drama_genres = genres_exploded[genres_exploded['genres'].str.contains('Drama', case=False, na=False)]

# Compter les occurrences des ratings pour les genres contenant 'Drama'
drama_rating_counts = drama_genres.groupby('rating').size()

# Afficher la répartition des ratings pour les genres contenant 'Drama'
print("Répartition des ratings pour les genres contenant 'Drama' :")
print(drama_rating_counts)

# Visualisation de la répartition des ratings pour les genres contenant 'Drama'
drama_rating_counts.plot(kind='bar', figsize=(10, 6), color='green')
plt.title("Répartition des Ratings pour les Genres contenant 'Drama'")
plt.xlabel("Rating")
plt.ylabel("Nombre de contenus")
plt.show()
# Out:
# Répartition des ratings pour les genres contenant 'Drama' :
# rating
# G           6
# NC-17       1
# NR         28
# PG         69
# PG-13     192
# R         376
# TV-14     962
# TV-G       36
# TV-MA    1264
# TV-PG     249
# TV-Y        3
# TV-Y7       1
# UR          2
# dtype: int64

# %%
movies
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                          United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Replace  NaN's values with a default category  (i.e , 'Unknown')
movies['rating'] = movies['rating'].fillna('Unknown')

# Vérifying
print(movies['rating'].isnull().sum())  # Should return 0
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

# Créer un objet LabelEncoder
label_encoder = LabelEncoder()

# Appliquer LabelEncoder sur la colonne 'rating' et créer une nouvelle colonne 'rating_encoded'
movies['rating_encoded'] = label_encoder.fit_transform(movies['rating'])

# Afficher les 5 premières lignes du dataset avec la nouvelle colonne
print(movies[['rating', 'rating_encoded']].head())
# Out:
#         rating  rating_encoded
# show_id
# s1       PG-13               7
# s2       TV-MA              11
# s3       TV-MA              11
# s4       TV-MA              11
# s5       TV-MA              11

# %%
movies
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                          United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Calculer la moyenne des ratings numériques
average_rating = movies['rating_encoded'].mean()

# Afficher la moyenne
print(f"La moyenne des ratings numériques est : {average_rating}")
# Out:
# La moyenne des ratings numériques est : 10.017940274781424

# %%
# Calculer la moyenne des ratings pour chaque genre
average_rating_by_genre = movies.groupby('genres')['rating_encoded'].mean()

# Afficher les résultats
print(average_rating_by_genre)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 2
#       1 # Calculer la moyenne des ratings pour chaque genre
# ----> 2 average_rating_by_genre = movies.groupby('genres')['rating_encoded'].mean()
#       4 # Afficher les résultats
#       5 print(average_rating_by_genre)
#
# File c:\Users\Alexandra\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
# ...
